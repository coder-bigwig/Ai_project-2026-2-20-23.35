# %% [markdown]
# # 实验四：NumPy数组使用方法初级实践
#
# 本实验聚焦 NumPy 数组的创建、索引、切片与基础运算。请在各题代码单元中补全实现并运行验证结果。

# %% [markdown]
# ## 1. 数组创建与属性
#
# - 创建指定形状数组
# - 查看 `shape` / `ndim` / `dtype` / `size`
# - 完成元素访问与修改

# %%
import numpy as np

# TODO: 按实验报告要求创建并操作数组
nums = np.array([[1, 2, 3], [4, 5, 6]])
print('shape:', nums.shape)
print('ndim:', nums.ndim)
print('dtype:', nums.dtype)
print('size:', nums.size)

nums[0, 1] = 7
print(nums)

# %% [markdown]
# ## 2. 索引、切片与常见函数
#
# 请完成：中心子矩阵提取、按行列统计、排序、拼接、拆分等操作。

# %%
# TODO: 按实验报告补齐其余题目代码
arr2 = np.arange(16).reshape(4, 4)
print('第三行:', arr2[2])
print('第一列:', arr2[:, 0])
print('中心2x2:\n', arr2[1:3, 1:3])
