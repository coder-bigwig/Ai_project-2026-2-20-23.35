# %% [markdown]
# # Python 基础语法练习
#
# 本实验将带你熟悉 Python 的基本语法。
#
# ## 1. 变量与输出

# %%
# 练习：定义一个变量 name，赋值为你的名字，然后打印 "Hello, [name]!"
name = "同学"
print(f"Hello, {name}!")

# %% [markdown]
# ## 2. 列表操作

# %%
# 练习：创建一个包含 1 到 5 的列表，然后计算它们的和
numbers = [1, 2, 3, 4, 5]
total = sum(numbers)
print(f"Sum: {total}")
