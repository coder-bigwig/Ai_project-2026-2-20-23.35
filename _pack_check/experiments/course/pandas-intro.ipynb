# %% [markdown]
# # Pandas 数据分析入门
#
# 本实验介绍 Pandas 的基本用法。
#
# ## 1. 创建 DataFrame

# %%
import pandas as pd

data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'London', 'Paris']
}

df = pd.DataFrame(data)
df
